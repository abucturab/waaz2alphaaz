# %% [markdown]
# # 02 — Baseline Evaluation
#
# **Goal:** Run MMS and Whisper zero-shot on aligned dua clips and measure WER/CER.
#
# This establishes the 'before' benchmark — how well the models work with no fine-tuning.
#
# Expected results:
# - Duas (Arabic content): WER 30–60%
# - Madeh (LuD content): WER 60–80%

# %%
# Phase 2 — requires data/dataset/ to be populated first (run notebook 01)
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))

# from waaz2alphaaz.baseline import run_baseline
