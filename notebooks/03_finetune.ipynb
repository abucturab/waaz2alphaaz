# %% [markdown]
# # 03 — MMS Adapter Fine-tuning
#
# **Goal:** Fine-tune a Lisan-ud-Dawat language adapter on top of `facebook/mms-300m`.
#
# Only the adapter weights (~2M params) are trained. The backbone is frozen.
# Runs on an 8GB GPU (Google Colab T4 free tier is sufficient).
#
# **Prerequisites:**
# - `data/dataset/` populated (notebook 01)
# - Baseline WER recorded (notebook 02)

# %%
# Phase 3 — requires data/dataset/ and baseline results
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))

# from waaz2alphaaz.finetune import train
