# %% [markdown]
# # 01 — OCR / Text Extraction Exploration
#
# **Goal:** Test text extraction on sample files from `data/raw/text_sources/`.
#
# Try each input format you have (.txt, .docx, .pdf, images) and verify:
# 1. Text is extracted correctly
# 2. Arabic characters render correctly
# 3. Diacritics are stripped as expected
# 4. Output looks ready for alignment

# %%
# Phase 1 — implement src/waaz2alphaaz/ocr.py first, then use it here
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))

# from waaz2alphaaz.ocr import extract_text
